# %%
import os
import pandas as pd
import geopandas as gpd

# necessary CRS for measuring area in feet (converting from lat/lon degrees CRS)
CRS_NYC = "EPSG:2263"

DATA_RAW = os.path.join("..", "data", "raw")
DATA_PROCESSED = os.path.join("..", "data", "processed")

PATH_BUILDINGS = os.path.join(DATA_RAW, "building_current", "nyc_building_footprints_current.zip")
PATH_NTA = os.path.join(DATA_RAW, "nta", "nyc_nta_2020.zip")

# %%
buildings = gpd.read_file(f"zip://{PATH_BUILDINGS}")
buildings = buildings.to_crs(CRS_NYC)

buildings["footprint_sqft"] = buildings.geometry.area

buildings[["footprint_sqft"]].describe()
# Out:
#        footprint_sqft
# count    1.082999e+06
# mean     1.609370e+03
# std      5.663732e+03
# min      3.247651e+01
# 25%      6.539524e+02
# 50%      9.593253e+02
# 75%      1.323959e+03
# max      1.171875e+06

# %%
nta = gpd.read_file(f"zip://{PATH_NTA}")

nta = nta.rename(columns={
    "nta2020": "NTACode",
    "ntaname": "NTAName"
})

nta = nta[["NTACode", "NTAName", "boroname", "geometry"]]
nta = nta.to_crs(CRS_NYC)

nta["nta_area_sqft"] = nta.geometry.area
nta["nta_area_sqmi"] = nta["nta_area_sqft"] / 27878400

nta.head()
# Out:
#   NTACode             NTAName  boroname  \
# 0  BK0101          Greenpoint  Brooklyn
# 1  BK0102        Williamsburg  Brooklyn
# 2  BK0103  South Williamsburg  Brooklyn
# 3  BK0104   East Williamsburg  Brooklyn
# 4  BK0201    Brooklyn Heights  Brooklyn
#
#                                             geometry  nta_area_sqft  \
# 0  POLYGON ((1003059.997 204572.025, 1002991.367 ...   3.532174e+07
# 1  POLYGON ((995851.916 203199.332, 995969.193 20...   2.885280e+07
# 2  POLYGON ((998047.21 196303.325, 998157.901 196...   1.520896e+07
# 3  POLYGON ((1005302.497 199455.73, 1005307.792 1...   5.226747e+07
# 4  POLYGON ((986367.736 190549.239, 985813.836 19...   9.982088e+06
#
#    nta_area_sqmi
# 0       1.266993
# 1       1.034952
# 2       0.545546
# 3       1.874838
# 4       0.358058

# %%
sample = buildings.sample(10000, random_state=42)

sample_join = gpd.sjoin(
    sample,
    nta,
    how="left",
    predicate="intersects"
)

# check proportion of buildings successfully assigned to NTAs
sample_join["NTACode"].notna().mean()
# Out:
# np.float64(0.9999000499750125)

# %%
# full spatial join to assign NTAs to buildings

buildings_nta = gpd.sjoin(
    buildings,
    nta,
    how="left",
    predicate="intersects"
).drop(columns=["index_right"])

# %%
# check proportion of buildings successfully assigned to NTAs
nta_density = (
    buildings_nta
    .groupby(["NTACode", "NTAName", "boroname"])
    .agg(
        building_count=("footprint_sqft", "count"),
        total_footprint_sqft=("footprint_sqft", "sum"),
        median_building_sqft=("footprint_sqft", "median")
    )
    .reset_index()
)

nta_density.head()
# Out:
#   NTACode             NTAName  boroname  building_count  total_footprint_sqft  \
# 0  BK0101          Greenpoint  Brooklyn            5147          1.340080e+07
# 1  BK0102        Williamsburg  Brooklyn            3646          1.037733e+07
# 2  BK0103  South Williamsburg  Brooklyn            2294          5.418461e+06
# 3  BK0104   East Williamsburg  Brooklyn            4939          1.745002e+07
# 4  BK0201    Brooklyn Heights  Brooklyn            1492          3.913004e+06
#
#    median_building_sqft
# 0           1248.021588
# 1           1334.824761
# 2           1408.694795
# 3           1354.539352
# 4           1358.771123

# %%
# merge back to nta to compute built density metrics and calculate ratios

nta_density = nta.merge(
    nta_density,
    on=["NTACode", "NTAName", "boroname"],
    how="left"
)

nta_density[[
    "building_count",
    "total_footprint_sqft",
    "median_building_sqft"
]] = nta_density[[
    "building_count",
    "total_footprint_sqft",
    "median_building_sqft"
]]

nta_density["built_area_ratio"] = (
    nta_density["total_footprint_sqft"] / nta_density["nta_area_sqft"]
)

nta_density["buildings_per_sqmi"] = (
    nta_density["building_count"] / nta_density["nta_area_sqmi"]
)

nta_density["built_sqft_per_sqmi"] = (
    nta_density["total_footprint_sqft"] / nta_density["nta_area_sqmi"]
)

# %%
# inspect built area ratio distribution

nta_density["built_area_ratio"].describe()
# Out:
# count    259.000000
# mean       0.227445
# std        0.133138
# min        0.000189
# 25%        0.149094
# 50%        0.247417
# 75%        0.324738
# max        0.549023
# Name: built_area_ratio, dtype: float64

# %%
# top 10 most built dense NTAs, sanity check showing manhattan which is correct, smaller NTAs large industrial areas

nta_density.sort_values("built_area_ratio", ascending=False).head(10)
# Out:
#     NTACode                              NTAName   boroname  \
# 130  MN0502                 Midtown-Times Square  Manhattan
# 129  MN0501  Midtown South-Flatiron-Union Square  Manhattan
# 121  MN0201      SoHo-Little Italy-Hudson Square  Manhattan
# 134  MN0604              East Midtown-Turtle Bay  Manhattan
# 128  MN0402                       Hell's Kitchen  Manhattan
# 140  MN0802        Upper East Side-Carnegie Hill  Manhattan
# 122  MN0202                    Greenwich Village  Manhattan
# 132  MN0602                             Gramercy  Manhattan
# 127  MN0401                 Chelsea-Hudson Yards  Manhattan
# 119  MN0102                 Tribeca-Civic Center  Manhattan
#
#                                               geometry  nta_area_sqft  \
# 130  POLYGON ((991725.244 217725.299, 992169.505 21...   2.455254e+07
# 129  POLYGON ((989555.974 211702.854, 989420.216 21...   1.487902e+07
# 121  POLYGON ((983469.159 204638.902, 983496.09 204...   1.291676e+07
# 134  POLYGON ((995598.36 215579.024, 995626.716 215...   1.313809e+07
# 128  POLYGON ((985324.423 221001.9, 985817.17 22072...   1.838232e+07
# 140  POLYGON ((998281.392 225347.968, 998145.231 22...   2.006536e+07
# 122  POLYGON ((987048.27 206851.147, 987057.852 206...   1.060046e+07
# 132  POLYGON ((990196.892 207745.371, 990187.613 20...   7.526000e+06
# 127  POLYGON ((983754.619 217001.185, 983857.657 21...   2.967175e+07
# 119  POLYGON ((984440.604 200699.422, 984402.913 20...   1.357825e+07
#
#      nta_area_sqmi  building_count  total_footprint_sqft  \
# 130       0.880701          1444.0          1.347990e+07
# 129       0.533711          1306.0          7.998146e+06
# 121       0.463325          1662.0          6.500400e+06
# 134       0.471264          1101.0          6.393684e+06
# 128       0.659375          1666.0          8.732165e+06
# 140       0.719746          2679.0          9.498898e+06
# 122       0.380239          1224.0          4.996409e+06
# 132       0.269958           818.0          3.486676e+06
# 127       1.064328          2075.0          1.318783e+07
# 119       0.487053           902.0          5.706854e+06
#
#      median_building_sqft  built_area_ratio  buildings_per_sqmi  \
# 130           5031.327741          0.549023         1639.602531
# 129           3405.174031          0.537545         2447.015022
# 121           2274.769680          0.503253         3587.114384
# 134           2142.036303          0.486652         2336.268575
# 128           1972.715628          0.475031         2526.635671
# 140           1908.545717          0.473398         3722.146907
# 122           2088.616231          0.471339         3219.027560
# 132           1996.561202          0.463284         3030.099995
# 127           2007.850335          0.444458         1949.587507
# 119           2960.023311          0.420294         1851.955068
#
#      built_sqft_per_sqmi
# 130         1.530587e+07
# 129         1.498590e+07
# 121         1.402989e+07
# 134         1.356709e+07
# 128         1.324310e+07
# 140         1.319757e+07
# 122         1.314018e+07
# 132         1.291562e+07
# 127         1.239076e+07
# 119         1.171711e+07

# %%
# borough-level summary statistics

borough_summary = (
    nta_density
    .groupby("boroname", as_index=False)
    .agg(
        avg_built_ratio=("built_area_ratio", "mean"),
        total_building_sqft=("total_footprint_sqft", "sum"),
        total_buildings=("building_count", "sum"),
        nta_count=("NTACode", "nunique")
    )
)

borough_summary
# Out:
#         boroname  avg_built_ratio  total_building_sqft  total_buildings  \
# 0          Bronx         0.212835         2.319491e+08         104508.0
# 1       Brooklyn         0.257159         5.225670e+08         330203.0
# 2      Manhattan         0.334825         2.102427e+08          44981.0
# 3         Queens         0.191468         5.925204e+08         461139.0
# 4  Staten Island         0.115797         1.893624e+08         142318.0
#
#    nta_count
# 0         50
# 1         69
# 2         38
# 3         82
# 4         23

# %%
out_path = os.path.join(DATA_PROCESSED, "nta_construction_density.parquet")
nta_density.to_parquet(out_path, index=False)
